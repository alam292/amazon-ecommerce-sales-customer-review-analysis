# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv("India_Ecommerce_Unclean_Dataset.csv")

# %%
df
# Out:
#           Order_ID  Order_Date Delivery_Date  Customer_Name  \
# 0      ORD00000001  28-09-2023    07-10-2023  Rohan Agarwal
# 1      ORD00000002  11-12-2023    12-12-2023   suresh Kumar
# 2      ORD00000003  24-10-2021    04-11-2021    Sunita Nair
# 3      ORD00000004  31-03-2024    06-04-2024      Pooja Das
# 4      ORD00000005  07-01-2022    07-11-2022      Kavya Sen
# ...            ...         ...           ...            ...
# 99995  ORD00099996         NaN           NaN   Pooja Chopra
# 99996  ORD00036659  21-05-2022    27-05-2022      meena Rao
# 99997  ORD00099998   03-Oct-23     14-Oct-23    Rahul Patel
# 99998  ORD00099999  25-10-2023    05-11-2023    POOJA Gupta
# 99999  ORD00100000  01-25-2024    02-06-2024    Kavya Reddy
#
#                       Customer_Email  Customer_Phone Customer_City  \
# 0       rohan.agarwal769@yahoo.co.in    9.186700e+11        Chenai
# 1         suresh.kumar998yahoo.co.in    9.193600e+11          PUNE
# ...

# %% [markdown]
# ## Data Overview

# %%
df.head(6)
# Out:
#       Order_ID  Order_Date Delivery_Date  Customer_Name  \
# 0  ORD00000001  28-09-2023    07-10-2023  Rohan Agarwal
# 1  ORD00000002  11-12-2023    12-12-2023   suresh Kumar
# 2  ORD00000003  24-10-2021    04-11-2021    Sunita Nair
# 3  ORD00000004  31-03-2024    06-04-2024      Pooja Das
# 4  ORD00000005  07-01-2022    07-11-2022      Kavya Sen
# 5  ORD00000006  08-09-2021    18-09-2021   Sanjay Joshi
#
#                  Customer_Email  Customer_Phone Customer_City  Customer_State  \
# 0  rohan.agarwal769@yahoo.co.in    9.186700e+11        Chenai              KA
# 1    suresh.kumar998yahoo.co.in    9.193600e+11          PUNE     Maharashtra
# 2    sunita.nair877@yahoo.co.in    9.173320e+11        Indore           Bihar
# 3         pooja.das184gmail.com    9.171830e+11       Kolkata  Andhra Pradesh
# 4      kavya.sen379@hotmail.com    9.189120e+11    Ahemadabad             NaN
# 5     sanjay.joshi235@gmail.com    9.199390e+11         DELHI       Rajasthan
#
# ...

# %%
df.tail()
# Out:
#           Order_ID  Order_Date Delivery_Date Customer_Name  \
# 99995  ORD00099996         NaN           NaN  Pooja Chopra
# 99996  ORD00036659  21-05-2022    27-05-2022     meena Rao
# 99997  ORD00099998   03-Oct-23     14-Oct-23   Rahul Patel
# 99998  ORD00099999  25-10-2023    05-11-2023   POOJA Gupta
# 99999  ORD00100000  01-25-2024    02-06-2024   Kavya Reddy
#
#                       Customer_Email  Customer_Phone Customer_City  \
# 99995      pooja.chopra868@gmail.com    9.180280e+11        Mumbai
# 99996       meena.rao409@hotmail.com    9.168080e+11          PUNE
# 99997  rahul.patel827@rediffmail.com    9.195280e+11           NaN
# 99998     pooja.gupta101@hotmail.com    9.171350e+11         DELHI
# 99999     kavya.reddy225@outlook.com    9.190550e+11          PUNE
#
#       Customer_State  Customer_Pincode     Region  ... Unit_Price_INR  \
# 99995             TN          792197.0      SOUTH  ...       32914.31
# ...

# %%
df.sample(3)
# Out:
#           Order_ID  Order_Date Delivery_Date Customer_Name  \
# 92913  ORD00092914  03-03-2021    10-03-2021  Lakshmi Iyer
# 95867  ORD00095868  19-11-2022    03-12-2022   Kavya Mehta
# 23091  ORD00023092  24-09-2020           NaN   Pooja Patel
#
#                    Customer_Email  Customer_Phone Customer_City  \
# 92913  lakshmi.iyer361yahoo.co.in    9.188980e+11        Bhopal
# 95867  kavya.mehta349@hotmail.com    9.170490e+11       Kolkata
# 23091  pooja.patel254@hotmail.com    9.160980e+11         Surat
#
#        Customer_State  Customer_Pincode Region  ... Unit_Price_INR  \
# 92913       Telangana          155830.0    NaN  ...      105413.34
# 95867     Maharashtra          217381.0    NaN  ...   INR 59207.71
# 23091  Madhya Pradesh          468481.0    NaN  ...       81430.21
#
#       Discount_Percent Tax_Percent Gross_Amount_INR  Net_Amount_INR  \
# 92913            12.44         0.0        316240.02       276899.76
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order_ID          99500 non-null   object
#  1   Order_Date        98990 non-null   object
#  2   Delivery_Date     97031 non-null   object
#  3   Customer_Name     99014 non-null   object
#  4   Customer_Email    99018 non-null   object
#  5   Customer_Phone    98996 non-null   float64
#  6   Customer_City     93215 non-null   object
#  7   Customer_State    88108 non-null   object
#  8   Customer_Pincode  99035 non-null   float64
#  9   Region            81744 non-null   object
#  10  Category          93659 non-null   object
#  11  Sub_Category      98995 non-null   object
#  12  Product_Name      97992 non-null   object
#  13  Product_SKU       100000 non-null  object
#  14  Quantity          100000 non-null  int64
#  15  Unit_Price_INR    99500 non-null   object
# ...

# %%
df.shape
# Out:
# (100000, 25)

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Delivery_Date', 'Customer_Name',
#        'Customer_Email', 'Customer_Phone', 'Customer_City', 'Customer_State',
#        'Customer_Pincode', 'Region', 'Category', 'Sub_Category',
#        'Product_Name', 'Product_SKU', 'Quantity', 'Unit_Price_INR',
#        'Discount_Percent', 'Tax_Percent', 'Gross_Amount_INR', 'Net_Amount_INR',
#        'Payment_Method', 'Payment_Status', 'Shipping_Method',
#        'Customer_Rating', 'Return_Status'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Customer_Phone  Customer_Pincode       Quantity  Discount_Percent  \
# count    9.899600e+04      99035.000000  100000.000000      98926.000000
# mean     8.993317e+11     527900.944262       6.189760         31.663346
# std      1.295726e+11     277762.101224      22.116066         25.363916
# min      1.030000e+02        103.000000      -9.000000       -196.870000
# 25%      9.169360e+11     297091.500000       3.000000         14.720000
# 50%      9.179565e+11     532496.000000       5.000000         30.250000
# 75%      9.189782e+11     766195.000000       7.000000         45.790000
# max      9.200000e+11     999993.000000     499.000000        199.850000
#
#         Tax_Percent  Gross_Amount_INR  Net_Amount_INR  Customer_Rating
# count  98027.000000      1.000000e+05    9.704500e+04     98006.000000
# mean      12.631714      4.794456e+05    3.718308e+05         3.035506
# std        9.839965      1.941093e+06    1.608757e+06         1.488470
# ...

# %%
df.describe(include = 'O')
# Out:
#            Order_ID  Order_Date Delivery_Date Customer_Name  \
# count         99500       98990         97031         99014
# unique        96590        4124          4167          1200
# top     ORD00058265  04-10-2020    06-12-2022   Priya Joshi
# freq              4          81            83           271
#
#                      Customer_Email Customer_City Customer_State Region  \
# count                         99018         93215          88108  81744
# unique                        96745            28             22      9
# top     rahul.sharma216@hotmail.com        Kanpur             WB  South
# freq                              3          3432           4071   9236
#
#            Category    Sub_Category               Product_Name Product_SKU  \
# count         93659           98995                      97992      100000
# unique           15              50                      39860       60513
# ...

# %%
df.describe(include = 'all')
# Out:
#            Order_ID  Order_Date Delivery_Date Customer_Name  \
# count         99500       98990         97031         99014
# unique        96590        4124          4167          1200
# top     ORD00058265  04-10-2020    06-12-2022   Priya Joshi
# freq              4          81            83           271
# mean            NaN         NaN           NaN           NaN
# std             NaN         NaN           NaN           NaN
# min             NaN         NaN           NaN           NaN
# 25%             NaN         NaN           NaN           NaN
# 50%             NaN         NaN           NaN           NaN
# 75%             NaN         NaN           NaN           NaN
# max             NaN         NaN           NaN           NaN
#
#                      Customer_Email  Customer_Phone Customer_City  \
# count                         99018    9.899600e+04         93215
# unique                        96745             NaN            28
# ...

# %%
df.dtypes
# Out:
# Order_ID             object
# Order_Date           object
# Delivery_Date        object
# Customer_Name        object
# Customer_Email       object
# Customer_Phone      float64
# Customer_City        object
# Customer_State       object
# Customer_Pincode    float64
# Region               object
# Category             object
# Sub_Category         object
# Product_Name         object
# Product_SKU          object
# Quantity              int64
# Unit_Price_INR       object
# Discount_Percent    float64
# Tax_Percent         float64
# Gross_Amount_INR    float64
# Net_Amount_INR      float64
# Payment_Method       object
# Payment_Status       object
# Shipping_Method      object
# Customer_Rating     float64
# Return_Status        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Order_ID              500
# Order_Date           1010
# Delivery_Date        2969
# Customer_Name         986
# Customer_Email        982
# Customer_Phone       1004
# Customer_City        6785
# Customer_State      11892
# Customer_Pincode      965
# Region              18256
# Category             6341
# Sub_Category         1005
# Product_Name         2008
# Product_SKU             0
# Quantity                0
# Unit_Price_INR        500
# Discount_Percent     1074
# Tax_Percent          1973
# Gross_Amount_INR        0
# Net_Amount_INR       2955
# Payment_Method      13220
# Payment_Status      17953
# Shipping_Method     22421
# Customer_Rating      1994
# Return_Status        9372
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for i in df:
    print(df[i].value_counts())
    print("===================")
# Out:
# Order_ID
# ORD00058265    4
# ORD00006914    3
# ORD00088367    3
# ORD00040288    3
# ORD00023256    3
#               ..
# ORD00033626    1
# ORD00033625    1
# ORD00033624    1
# ORD00033623    1
# ORD00100000    1
# Name: count, Length: 96590, dtype: int64
# ...
# Order_Date
# 04-10-2020    81
# 10-01-2020    81
# 23-12-2021    79
# 08-07-2020    78
# 09-02-2023    78
#               ..
# 30-Oct-21      1
# 11-30-2022     1
# 18-Dec-23      1
# 23-Mar-20      1
# 17-May-22      1
# Name: count, Length: 4124, dtype: int64
# ...
# Delivery_Date
# 06-12-2022    83
# 09-09-2022    83
# 12-06-2022    80
# 01-03-2020    80
# 05-09-2022    78
#               ..
# 04-25-2024     1
# 01-23-2024     1
# 09-13-2021     1
# 11-Sep-23      1
# 29-May-24      1
# Name: count, Length: 4167, dtype: int64
# ...
# Customer_Name
# Priya Joshi      271
# Rahul Joshi      259
# Arun Iyer        258
# Sanjay Chopra    258
# Kavya Sharma     254
#                 ...
# rohan Verma        5
# rohan Iyer         5
# ...

# %%
for i in df:
    print(df[i].unique())
    print('=============================================================')
# Out:
# ['ORD00000001' 'ORD00000002' 'ORD00000003' ... 'ORD00099998' 'ORD00099999'
#  'ORD00100000']
# ...
# ['28-09-2023' '11-12-2023' '24-10-2021' ... '03-23-2024' '05-Nov-20'
#  '17-May-22']
# ...
# ['07-10-2023' '12-12-2023' '04-11-2021' ... '04-15-2022' '03-Sep-20'
#  '29-May-24']
# ...
# ['Rohan Agarwal' 'suresh Kumar' 'Sunita Nair' ... 'DIVYA Mishra'
#  'POOJA Das' 'amit Reddy']
# ...
# ['rohan.agarwal769@yahoo.co.in' 'suresh.kumar998yahoo.co.in'
#  'sunita.nair877@yahoo.co.in' ... 'rahul.patel827@rediffmail.com'
#  'pooja.gupta101@hotmail.com' 'kavya.reddy225@outlook.com']
# ...
# [9.18670e+11 9.19360e+11 9.17332e+11 ... 9.98100e+03 1.74600e+03
#  9.93600e+03]
# ...
# ['Chenai' 'PUNE' 'Indore' 'Kolkata' 'Ahemadabad' 'DELHI' 'Mumbai' 'Kanpur'
#  'Ahmedabad' 'Bangalroe' 'kolkata' nan 'Delhi' 'Bangalore' 'Surat'
#  'Vadodara' 'Visakhapatnam' 'Chennai' 'Lucknow' 'Thane' 'Ghaziabad'
#  'Hydrabad' 'Jaipur' 'Pune' 'mumbai' 'Bhopal' 'Hyderabad' 'Patna' 'Nagpur']
# ...
