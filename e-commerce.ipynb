# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# ## Data Collection

# %%
df = pd.read_excel("amazon_ecommerce_messy.xlsx")

# %%
df

# %% [markdown]
# ## Data Understanding

# %%
df.head()

# %%
df.tail()

# %%
df.sample(5)

# %%
df.info
